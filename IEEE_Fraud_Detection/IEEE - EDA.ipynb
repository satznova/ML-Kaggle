# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
from  matplotlib.ticker import PercentFormatter
import seaborn as sns

# Figures inline 
# %matplotlib inline
# set visualization style
sns.set()

# %%
train_identity    = pd.read_csv("data/train_identity.csv")
train_transaction = pd.read_csv("data/train_transaction.csv")
test_identity     = pd.read_csv("data/test_identity.csv")
test_transaction  = pd.read_csv("data/test_transaction.csv")

# %% [markdown]
# ### Transaction data

# %%
train_transaction.isnull().sum()
# Out:
# TransactionID          0
# isFraud                0
# TransactionDT          0
# TransactionAmt         0
# ProductCD              0
# card1                  0
# card2               8933
# card3               1565
# card4               1577
# card5               4259
# card6               1571
# addr1              65706
# addr2              65706
# dist1             352271
# dist2             552913
# P_emaildomain      94456
# R_emaildomain     453249
# C1                     0
# C2                     0
# C3                     0
# C4                     0
# C5                     0
# C6                     0
# C7                     0
# C8                     0
# C9                     0
# C10                    0
# C11                    0
# C12                    0
# C13                    0
#                    ...
# V310                  12
# V311                  12
# V312                  12
# V313                1269
# V314                1269
# V315                1269
# ...

# %%
train_transaction.head(n=10)
# Out:
#    TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  card1  \
# 0        2987000        0          86400            68.5         W  13926
# 1        2987001        0          86401            29.0         W   2755
# 2        2987002        0          86469            59.0         W   4663
# 3        2987003        0          86499            50.0         W  18132
# 4        2987004        0          86506            50.0         H   4497
# 5        2987005        0          86510            49.0         W   5937
# 6        2987006        0          86522           159.0         W  12308
# 7        2987007        0          86529           422.5         W  12695
# 8        2987008        0          86535            15.0         H   2803
# 9        2987009        0          86536           117.0         W  17399
#
#    card2  card3       card4  card5  ... V330  V331  V332  V333  V334 V335  \
# 0    NaN  150.0    discover  142.0  ...  NaN   NaN   NaN   NaN   NaN  NaN
# ...

# %%
train_transaction.describe()
# Out:
#        TransactionID        isFraud  TransactionDT  TransactionAmt  \
# count   5.905400e+05  590540.000000   5.905400e+05   590540.000000
# mean    3.282270e+06       0.034990   7.372311e+06      135.027176
# std     1.704744e+05       0.183755   4.617224e+06      239.162522
# min     2.987000e+06       0.000000   8.640000e+04        0.251000
# 25%     3.134635e+06       0.000000   3.027058e+06       43.321000
# 50%     3.282270e+06       0.000000   7.306528e+06       68.769000
# 75%     3.429904e+06       0.000000   1.124662e+07      125.000000
# max     3.577539e+06       1.000000   1.581113e+07    31937.391000
#
#                card1          card2          card3          card5  \
# count  590540.000000  581607.000000  588975.000000  586281.000000
# mean     9898.734658     362.555488     153.194925     199.278897
# std      4901.170153     157.793246      11.336444      41.244453
# min      1000.000000     100.000000     100.000000     100.000000
# ...

# %% [markdown]
# ### Identity data

# %%
train_identity.isnull().sum()
# Out:
# TransactionID         0
# id_01                 0
# id_02              3361
# id_03             77909
# id_04             77909
# id_05              7368
# id_06              7368
# id_07            139078
# id_08            139078
# id_09             69307
# id_10             69307
# id_11              3255
# id_12                 0
# id_13             16913
# id_14             64189
# id_15              3248
# id_16             14893
# id_17              4864
# id_18             99120
# id_19              4915
# id_20              4972
# id_21            139074
# id_22            139064
# id_23            139064
# id_24            139486
# id_25            139101
# id_26            139070
# id_27            139064
# id_28              3255
# id_29              3255
# id_30             66668
# id_31              3951
# id_32             66647
# id_33             70944
# id_34             66428
# id_35              3248
# id_36              3248
# id_37              3248
# ...

# %%
train_identity.head(n=10)
# Out:
#    TransactionID  id_01     id_02  id_03  id_04  id_05  id_06  id_07  id_08  \
# 0        2987004    0.0   70787.0    NaN    NaN    NaN    NaN    NaN    NaN
# 1        2987008   -5.0   98945.0    NaN    NaN    0.0   -5.0    NaN    NaN
# 2        2987010   -5.0  191631.0    0.0    0.0    0.0    0.0    NaN    NaN
# 3        2987011   -5.0  221832.0    NaN    NaN    0.0   -6.0    NaN    NaN
# 4        2987016    0.0    7460.0    0.0    0.0    1.0    0.0    NaN    NaN
# 5        2987017   -5.0   61141.0    3.0    0.0    3.0    0.0    NaN    NaN
# 6        2987022  -15.0       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7        2987038    0.0   31964.0    0.0    0.0    0.0  -10.0    NaN    NaN
# 8        2987040  -10.0  116098.0    0.0    0.0    0.0    0.0    NaN    NaN
# 9        2987048   -5.0  257037.0    NaN    NaN    0.0    0.0    NaN    NaN
#
#    id_09  ...                id_31  id_32      id_33           id_34  id_35  \
# ...

# %%
train_identity.describe()
# Out:
#        TransactionID          id_01          id_02         id_03  \
# count   1.442330e+05  144233.000000  140872.000000  66324.000000
# mean    3.236329e+06     -10.170502  174716.584708      0.060189
# std     1.788496e+05      14.347949  159651.816856      0.598231
# min     2.987004e+06    -100.000000       1.000000    -13.000000
# 25%     3.077142e+06     -10.000000   67992.000000      0.000000
# 50%     3.198818e+06      -5.000000  125800.500000      0.000000
# 75%     3.392923e+06      -5.000000  228749.000000      0.000000
# max     3.577534e+06       0.000000  999595.000000     10.000000
#
#               id_04          id_05          id_06        id_07        id_08  \
# count  66324.000000  136865.000000  136865.000000  5155.000000  5155.000000
# mean      -0.058938       1.615585      -6.698710    13.285354   -38.600388
# std        0.701015       5.249856      16.491104    11.384207    26.084899
# ...

# %%
train_identity['DeviceType'].unique()
# Out:
# array(['mobile', 'desktop', nan], dtype=object)

# %% [markdown]
# ### 1st base Model using EDA : No Frauds
#
# > Build a quick-and-dirty model. Then reiterate to get better score.

# %%
sns.countplot(x='isFraud', data=train_transaction)

# %%
ax = sns.countplot(x='isFraud', data=train_transaction)

plt.title('Number of Frauds')
plt.xlabel('isFraud')

total = len(train_transaction['TransactionID'])
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %% [markdown]
# > **Take-away:** in the training transaction set, less frauds happended. Let's then build a first model that predicts that no frauds happened.

# %%
test_transaction['isFraud'] = 0

test_transaction[['TransactionID', 'isFraud']].to_csv('predictions/no_frauds.csv', index=False)

# Score: 0.500

# %% [markdown]
# ---

# %%
sns.countplot(x='card4', data=train_transaction);

# %%
sns.catplot(x='isFraud', col='card4', kind='count', data=train_transaction)

# %% [markdown]
# > **Take-away:** dasd

# %%
sns.countplot(x='ProductCD', data=train_transaction);

# %%
sns.catplot(x='isFraud', col='ProductCD', kind='count', data=train_transaction)

# %%
sns.distplot(train_transaction.TransactionAmt)

# %%
corr_matrix = train_transaction.corr()

# %%
corr_matrix
# Out:
#                 TransactionID   isFraud  TransactionDT  TransactionAmt  \
# TransactionID        1.000000  0.014166       0.998280        0.012025
# isFraud              0.014166  1.000000       0.013103        0.011320
# TransactionDT        0.998280  0.013103       1.000000        0.011920
# TransactionAmt       0.012025  0.011320       0.011920        1.000000
# card1                0.010122 -0.013640       0.010625       -0.005725
# card2               -0.019900  0.003388      -0.019202        0.016136
# card3               -0.010091  0.154151      -0.011222       -0.109785
# card5               -0.023900 -0.033580      -0.024132        0.003061
# addr1               -0.000370  0.005596      -0.000051       -0.007421
# addr2                0.057213 -0.030387       0.051972        0.028312
# dist1               -0.027043  0.021522      -0.027295        0.026146
# dist2               -0.026273 -0.019054      -0.026860        0.023143
# ...

# %%
# plot the heatmap
sns.heatmap(corr_matrix)
